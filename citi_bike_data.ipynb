# %%
#import dependencies
import pandas as pd
import numpy as np

# %%
#import csv data
input_csv = pd.read_csv("Resources/citibike-tripdata_sept_oct_2020.csv", delimiter=',', skipinitialspace=True)
input_csv.shape
# Out:
# (83919, 15)

# %%
#display data
input_csv
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0               156   02:40.3  05:17.0              3186      Grove St PATH
# 1               143   02:53.5  05:17.0              3186      Grove St PATH
# 2               305   04:31.3  09:36.4              3273       Manila & 1st
# 3              1097   05:18.4  23:36.1              3199       Newport Pkwy
# 4               277   09:17.6  13:55.5              3199       Newport Pkwy
# ...             ...       ...      ...               ...                ...
# 83914           270   05:35.1  10:05.3              3207        Oakland Ave
# 83915           400   09:03.5  15:44.0              3209       Brunswick St
# 83916           206   11:34.3  15:00.5              3195            Sip Ave
# 83917           216   11:49.2  15:25.7              3195            Sip Ave
# 83918           418   12:31.8  19:30.5              3267       Morris Canal
#
# ...
